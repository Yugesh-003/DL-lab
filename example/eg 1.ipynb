# %%
# Importing libraries
import numpy as np
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.utils import to_categorical

# Example dataset
X = np.random.rand(100, 10)   # 100 samples, 10 features
y = np.random.randint(0, 4, 100)  # 100 labels, 4 classes (0,1,2,3)

# One-hot encoding
y = to_categorical(y, num_classes=4)

# Define model
model = Sequential()
model.add(Dense(16, activation='relu', input_shape=(10,)))      # Hidden layer 1
model.add(Dense(8, activation='relu'))                                  # Hidden layer 2
model.add(Dense(4, activation='softmax'))       # 4 neurons in output layer to classify 4 classes

# Compile the model
model.compile(
    optimizer='adam',
    loss='categorical_crossentropy',
    metrics=['accuracy']
)

# Train the model
model.fit(X, y, epochs=20, batch_size=8)

# Evaluate the model
loss, acc = model.evaluate(X, y)
print("Accuracy:", acc)
# Out:
# c:\Users\Yugesh\anaconda3\envs\tf_gpu_env\lib\site-packages\requests\__init__.py:86: RequestsDependencyWarning: Unable to find acceptable character detection dependency (chardet or charset_normalizer).
#   warnings.warn(
# c:\Users\Yugesh\anaconda3\envs\tf_gpu_env\lib\site-packages\h5py\__init__.py:36: UserWarning: h5py is running against HDF5 1.14.6 when it was built against 1.14.5, this may cause problems
#   _warn(("h5py is running against HDF5 {0} when it was built against {1}, "
# Epoch 1/20
# 13/13 [==============================] - 3s 4ms/step - loss: 1.3947 - accuracy: 0.2500
# Epoch 2/20
# 13/13 [==============================] - 0s 3ms/step - loss: 1.3889 - accuracy: 0.2600
# Epoch 3/20
# 13/13 [==============================] - 0s 3ms/step - loss: 1.3845 - accuracy: 0.2600
# Epoch 4/20
# 13/13 [==============================] - 0s 3ms/step - loss: 1.3829 - accuracy: 0.3200
# Epoch 5/20
# 13/13 [==============================] - 0s 4ms/step - loss: 1.3796 - accuracy: 0.3100
# Epoch 6/20
# 13/13 [==============================] - 0s 4ms/step - loss: 1.3772 - accuracy: 0.3100
# Epoch 7/20
# 13/13 [==============================] - 0s 4ms/step - loss: 1.3749 - accuracy: 0.3200
# Epoch 8/20
# 13/13 [==============================] - 0s 4ms/step - loss: 1.3731 - accuracy: 0.3200
# Epoch 9/20
# 13/13 [==============================] - 0s 4ms/step - loss: 1.3713 - accuracy: 0.3200
# Epoch 10/20
# 13/13 [==============================] - 0s 3ms/step - loss: 1.3698 - accuracy: 0.3600
# Epoch 11/20
# 13/13 [==============================] - 0s 4ms/step - loss: 1.3678 - accuracy: 0.3800
# Epoch 12/20
# 13/13 [==============================] - 0s 3ms/step - loss: 1.3670 - accuracy: 0.3500
# Epoch 13/20
# 13/13 [==============================] - 0s 3ms/step - loss: 1.3650 - accuracy: 0.3500
# Epoch 14/20
# 13/13 [==============================] - 0s 3ms/step - loss: 1.3631 - accuracy: 0.3700
# Epoch 15/20
# 13/13 [==============================] - 0s 3ms/step - loss: 1.3615 - accuracy: 0.3600
# Epoch 16/20
# 13/13 [==============================] - 0s 3ms/step - loss: 1.3598 - accuracy: 0.3800
# Epoch 17/20
# 13/13 [==============================] - 0s 3ms/step - loss: 1.3581 - accuracy: 0.3400
# Epoch 18/20
# 13/13 [==============================] - 0s 3ms/step - loss: 1.3563 - accuracy: 0.3600
# Epoch 19/20
# 13/13 [==============================] - 0s 3ms/step - loss: 1.3553 - accuracy: 0.3500
# Epoch 20/20
# 13/13 [==============================] - 0s 3ms/step - loss: 1.3528 - accuracy: 0.3400
# 4/4 [==============================] - 0s 3ms/step - loss: 1.3510 - accuracy: 0.3500
# Accuracy: 0.3499999940395355
