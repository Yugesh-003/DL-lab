# %% [markdown]
# <a href="https://colab.research.google.com/github/Yugesh-003/DL-lab/blob/master/tokenizations/tokenization_basic.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import nltk
from nltk.tokenize import word_tokenize, sent_tokenize

# Download required resources (only once)
nltk.download('punkt_tab')
# Out:
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt_tab.zip.
# True

# %%
# Input text
text = "Hello! We are from III B.Sc CS(DSA). We are learning NLP. It's really interesting."

# Split into sentences
# Sentence tokenize
# sent_tokenize() -> It automatically detects sentence boundaries (like . ! ?)
# and splits a block of text into a list of individual sentences.
sentences = sent_tokenize(text)
print(sentences)
# Out:
# ['Hello!', 'We are from III B.Sc CS(DSA).', 'We are learning NLP.', "It's really interesting."]

# %%
print("Sentences:")
# enumerate() adds a counter (index) to an iterable (like a list).

for i, sentence in enumerate(sentences, 1):
    print(f"{i}: {sentence}")
# Out:
# Sentences:
# 1: Hello!
# 2: We are from III B.Sc CS(DSA).
# 3: We are learning NLP.
# 4: It's really interesting.

# %%
# Split into words
words = word_tokenize(text)
print("\nWords:")
print(words)
# Out:
# Words:
# ['Hello', '!', 'We', 'are', 'from', 'III', 'B.Sc', 'CS', '(', 'DSA', ')', '.', 'We', 'are', 'learning', 'NLP', '.', 'It', "'s", 'really', 'interesting', '.']

# %%
fruits = ['apple', 'banana', 'cherry']

for index, fruit in enumerate(fruits):
    print(index, fruit)
# Out:
# 0 apple
# 1 banana
# 2 cherry

# %%
text = "hello"

for i, char in enumerate(text,1):
    print(i, char)
# Out:
# 1 h
# 2 e
# 3 l
# 4 l
# 5 o
